# %% [markdown]
# # LIBS

# %%
import pandas as pd

# %% [markdown]
# # IMPORT

# %%
df_path = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\df_merged"
df = pd.read_csv(df_path, index_col=0)

df
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_19632\4169470879.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(df_path, index_col=0)
#                                    NOME_DELEGACIA   NOME_MUNICIPIO  NUM_BO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS          08ª DDM SAO MATEUS          S.PAULO  AC0851
# DEL.SEC.8º SAO MATEUS    54º D.P. CID. TIRADENTES          S.PAULO       4
# DEL.SEC.5º LESTE           29º D.P. VILA PRUDENTE          S.PAULO       7
# DEL.SEC.1º CENTRO                     01º D.P. SE          S.PAULO       8
# DEL.SEC.1º CENTRO                06º D.P. CAMBUCI          S.PAULO       8
# ...                                           ...              ...     ...
# DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IR7765
# DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IS4320
# DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IU0529
# DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IU3825
# DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IU8115
#
#                          ANO_BO DATA_REGISTRO   DATA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS      2022    2022-01-13  2021-09-01 00:00:00
# DEL.SEC.8º SAO MATEUS      2022    2022-01-03  2021-12-31 00:00:00
# DEL.SEC.5º LESTE           2022    2022-01-04  2021-12-30 00:00:00
# DEL.SEC.1º CENTRO          2022    2022-01-03  2022-01-03 00:00:00
# DEL.SEC.1º CENTRO          2022    2022-01-03  2022-01-03 00:00:00
# ...                         ...           ...                  ...
# DEL.SEC.TABOÃO DA SERRA    2024    2024-06-25           2024-06-25
# DEL.SEC.TABOÃO DA SERRA    2024    2024-06-26           2024-06-25
# DEL.SEC.TABOÃO DA SERRA    2024    2024-06-27           2024-06-27
# DEL.SEC.TABOÃO DA SERRA    2024    2024-06-27           2024-06-27
# DEL.SEC.TABOÃO DA SERRA    2024    2024-06-27           2024-06-27
#
#                         HORA_OCORRENCIA_BO     DESC_PERIODO DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                  NaN  EM HORA INCERTA        Residência
# DEL.SEC.8º SAO MATEUS             15:20:00              NaN       Via pública
# DEL.SEC.5º LESTE                       NaN  EM HORA INCERTA  Terminal/Estação
# DEL.SEC.1º CENTRO                 16:00:00              NaN       Via pública
# DEL.SEC.1º CENTRO                 13:30:00              NaN       Via pública
# ...                                    ...              ...               ...
# DEL.SEC.TABOÃO DA SERRA           12:58:42              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           20:40:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           03:13:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           09:40:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           13:27:44              NaN       Via Pública
#
#                                                 BAIRRO  ...  LONGITUDE  \
# NOME_SECCIONAL                                          ...
# DEL.SEC.8º SAO MATEUS                               SE  ...   0.000000
# DEL.SEC.8º SAO MATEUS    Centro Histórico de São Paulo  ... -46.632520
# DEL.SEC.5º LESTE                                    SE  ... -46.631091
# DEL.SEC.1º CENTRO                            Liberdade  ... -46.625872
# DEL.SEC.1º CENTRO                            LIBERDADE  ... -46.630224
# ...                                                ...  ...        ...
# DEL.SEC.TABOÃO DA SERRA                      J TRIANON  ... -46.795586
# DEL.SEC.TABOÃO DA SERRA                   J S SALVADOR  ... -46.788974
# DEL.SEC.TABOÃO DA SERRA                   JARDIM SUINA  ... -46.794137
# DEL.SEC.TABOÃO DA SERRA                  JARDIM RECORD  ... -46.789868
# DEL.SEC.TABOÃO DA SERRA                   MARIA HELENA  ... -46.805860
#
#                         NOME_DELEGACIA_CIRCUNSCRIÇÃO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                    01º D.P. SE
# DEL.SEC.8º SAO MATEUS                    01º D.P. SE
# DEL.SEC.5º LESTE                         01º D.P. SE
# DEL.SEC.1º CENTRO                        01º D.P. SE
# DEL.SEC.1º CENTRO                        01º D.P. SE
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA     02º D.P. TABOÃO DA SERRA
#
#                          NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                              DECAP
# DEL.SEC.8º SAO MATEUS                              DECAP
# DEL.SEC.5º LESTE                                   DECAP
# DEL.SEC.1º CENTRO                                  DECAP
# DEL.SEC.1º CENTRO                                  DECAP
# ...                                                  ...
# DEL.SEC.TABOÃO DA SERRA                          DEMACRO
# DEL.SEC.TABOÃO DA SERRA                          DEMACRO
# DEL.SEC.TABOÃO DA SERRA                          DEMACRO
# DEL.SEC.TABOÃO DA SERRA                          DEMACRO
# DEL.SEC.TABOÃO DA SERRA                          DEMACRO
#
#                          NOME_SECCIONAL_CIRCUNSCRIÇÃO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS               DEL.SEC.1º CENTRO
# DEL.SEC.8º SAO MATEUS               DEL.SEC.1º CENTRO
# DEL.SEC.5º LESTE                    DEL.SEC.1º CENTRO
# DEL.SEC.1º CENTRO                   DEL.SEC.1º CENTRO
# DEL.SEC.1º CENTRO                   DEL.SEC.1º CENTRO
# ...                                               ...
# DEL.SEC.TABOÃO DA SERRA       DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA       DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA       DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA       DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA       DEL.SEC.TABOÃO DA SERRA
#
#                         NOME_MUNICIPIO_CIRCUNSCRIÇÃO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                        S.PAULO
# DEL.SEC.8º SAO MATEUS                        S.PAULO
# DEL.SEC.5º LESTE                             S.PAULO
# DEL.SEC.1º CENTRO                            S.PAULO
# DEL.SEC.1º CENTRO                            S.PAULO
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
#
#                                                 RUBRICA        DESCR_CONDUTA  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                Art. 213 - Estupro                  NaN
# DEL.SEC.8º SAO MATEUS                  Furto (art. 155)  INTERIOR DE VEICULO
# DEL.SEC.5º LESTE                       Furto (art. 155)           TRANSEUNTE
# DEL.SEC.1º CENTRO                      Furto (art. 155)  INTERIOR DE VEICULO
# DEL.SEC.1º CENTRO                      Furto (art. 155)  INTERIOR DE VEICULO
# ...                                                 ...                  ...
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
#
#                                  NATUREZA_APURADA MES_ESTATISTICA  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                     ESTUPRO               1
# DEL.SEC.8º SAO MATEUS              FURTO - OUTROS               1
# DEL.SEC.5º LESTE                   FURTO - OUTROS               1
# DEL.SEC.1º CENTRO                  FURTO - OUTROS               1
# DEL.SEC.1º CENTRO                  FURTO - OUTROS               1
# ...                                           ...             ...
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
#
#                         ANO_ESTATISTICA
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS              2022
# DEL.SEC.8º SAO MATEUS              2022
# DEL.SEC.5º LESTE                   2022
# DEL.SEC.1º CENTRO                  2022
# DEL.SEC.1º CENTRO                  2022
# ...                                 ...
# DEL.SEC.TABOÃO DA SERRA            2024
# DEL.SEC.TABOÃO DA SERRA            2024
# DEL.SEC.TABOÃO DA SERRA            2024
# DEL.SEC.TABOÃO DA SERRA            2024
# DEL.SEC.TABOÃO DA SERRA            2024
#
# [3589574 rows x 23 columns]

# %% [markdown]
# # CLEANING

# %%
# exluindo colunas desnescessárias para o estudo
# dropping unnecessary columns to the study

del_columns = [
    'NOME_DEPARTAMENTO', 
    'LATITUDE', 
    'NOME_SECCIONAL', 
    'LONGITUDE', 
    'NOME_DELEGACIA', 
    'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 
    'NUM_BO', 
    'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO',
    'ANO_BO', 
    'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 
    'LOGRADOURO', 
    'NOME_MUNICIPIO_CIRCUNSCRIÇÃO', 
    'NUMERO_LOGRADOURO', 
    'DESCR_CONDUTA',
    'NATUREZA_APURADA'
]

df_col = df.drop(columns=[col for col in del_columns if col in df.columns])
df_col
# Out:
#                           NOME_MUNICIPIO DATA_REGISTRO   DATA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS            S.PAULO    2022-01-13  2021-09-01 00:00:00
# DEL.SEC.8º SAO MATEUS            S.PAULO    2022-01-03  2021-12-31 00:00:00
# DEL.SEC.5º LESTE                 S.PAULO    2022-01-04  2021-12-30 00:00:00
# DEL.SEC.1º CENTRO                S.PAULO    2022-01-03  2022-01-03 00:00:00
# DEL.SEC.1º CENTRO                S.PAULO    2022-01-03  2022-01-03 00:00:00
# ...                                  ...           ...                  ...
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2024-06-25           2024-06-25
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2024-06-26           2024-06-25
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2024-06-27           2024-06-27
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2024-06-27           2024-06-27
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2024-06-27           2024-06-27
#
#                         HORA_OCORRENCIA_BO     DESC_PERIODO DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                  NaN  EM HORA INCERTA        Residência
# DEL.SEC.8º SAO MATEUS             15:20:00              NaN       Via pública
# DEL.SEC.5º LESTE                       NaN  EM HORA INCERTA  Terminal/Estação
# DEL.SEC.1º CENTRO                 16:00:00              NaN       Via pública
# DEL.SEC.1º CENTRO                 13:30:00              NaN       Via pública
# ...                                    ...              ...               ...
# DEL.SEC.TABOÃO DA SERRA           12:58:42              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           20:40:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           03:13:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           09:40:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           13:27:44              NaN       Via Pública
#
#                                                 BAIRRO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                               SE
# DEL.SEC.8º SAO MATEUS    Centro Histórico de São Paulo
# DEL.SEC.5º LESTE                                    SE
# DEL.SEC.1º CENTRO                            Liberdade
# DEL.SEC.1º CENTRO                            LIBERDADE
# ...                                                ...
# DEL.SEC.TABOÃO DA SERRA                      J TRIANON
# DEL.SEC.TABOÃO DA SERRA                   J S SALVADOR
# DEL.SEC.TABOÃO DA SERRA                   JARDIM SUINA
# DEL.SEC.TABOÃO DA SERRA                  JARDIM RECORD
# DEL.SEC.TABOÃO DA SERRA                   MARIA HELENA
#
#                                                 RUBRICA  MES_ESTATISTICA  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                Art. 213 - Estupro                1
# DEL.SEC.8º SAO MATEUS                  Furto (art. 155)                1
# DEL.SEC.5º LESTE                       Furto (art. 155)                1
# DEL.SEC.1º CENTRO                      Furto (art. 155)                1
# DEL.SEC.1º CENTRO                      Furto (art. 155)                1
# ...                                                 ...              ...
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
#
#                          ANO_ESTATISTICA
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS               2022
# DEL.SEC.8º SAO MATEUS               2022
# DEL.SEC.5º LESTE                    2022
# DEL.SEC.1º CENTRO                   2022
# DEL.SEC.1º CENTRO                   2022
# ...                                  ...
# DEL.SEC.TABOÃO DA SERRA             2024
# DEL.SEC.TABOÃO DA SERRA             2024
# DEL.SEC.TABOÃO DA SERRA             2024
# DEL.SEC.TABOÃO DA SERRA             2024
# DEL.SEC.TABOÃO DA SERRA             2024
#
# [3589574 rows x 10 columns]

# %%
# filtrando os dados de santos
# filtring santos data 

def city_filter(df, col, city):
    df[col] = df[col].str.strip().str.upper()

    return df[df[col] == city]

df_city = city_filter(df_col, "NOME_MUNICIPIO", "SANTOS")

df_city
# Out:
#                                 NOME_MUNICIPIO DATA_REGISTRO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                          SANTOS    2022-01-16
# DEL.SEC.SANTOS                          SANTOS    2022-01-11
# DELEGACIA ELETRONICA                    SANTOS    2022-01-13
# DELEGACIA ELETRONICA                    SANTOS    2022-01-19
# DEL.SEC.SANTOS                          SANTOS    2022-01-06
# ...                                        ...           ...
# DIV.POL.PORTO/AERO/PROT.TURISTA         SANTOS    2024-06-13
# DELEGACIA ELETRONICA                    SANTOS    2024-06-09
# DELEGACIA ELETRONICA                    SANTOS    2024-06-21
# DEL.SEC.SANTOS                          SANTOS    2024-06-27
# DEIC - DEINTER 6                        SANTOS    2024-06-18
#
#                                   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                   2022-01-16 00:00:00           13:00:00
# DEL.SEC.SANTOS                   2021-12-19 00:00:00           22:40:00
# DELEGACIA ELETRONICA             2022-01-12 00:00:00           17:40:00
# DELEGACIA ELETRONICA             2021-12-07 00:00:00           10:15:00
# DEL.SEC.SANTOS                   2022-01-06 00:00:00                NaN
# ...                                              ...                ...
# DIV.POL.PORTO/AERO/PROT.TURISTA           2024-06-12           23:30:00
# DELEGACIA ELETRONICA                      2024-06-08           00:20:00
# DELEGACIA ELETRONICA                      2024-06-21                NaN
# DEL.SEC.SANTOS                            2024-06-08                NaN
# DEIC - DEINTER 6                          2024-06-17           17:50:00
#
#                                 DESC_PERIODO DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                           NaN       Via pública
# DEL.SEC.SANTOS                           NaN          Internet
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DEL.SEC.SANTOS                    PELA MANHÃ       Via pública
# ...                                      ...               ...
# DIV.POL.PORTO/AERO/PROT.TURISTA          NaN       Ferroviário
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DELEGACIA ELETRONICA              Pela manhã       Via Pública
# DEL.SEC.SANTOS                       A tarde       Via Pública
# DEIC - DEINTER 6                         NaN              Casa
#
#                                             BAIRRO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                   VILA JOQUEI CLUBE
# DEL.SEC.SANTOS                           BOA VISTA
# DELEGACIA ELETRONICA                        ALEMOA
# DELEGACIA ELETRONICA                        ALEMOA
# DEL.SEC.SANTOS                              CENTRO
# ...                                            ...
# DIV.POL.PORTO/AERO/PROT.TURISTA            PAQUETA
# DELEGACIA ELETRONICA                   OUTEIRINHOS
# DELEGACIA ELETRONICA                   PORTO SABOO
# DEL.SEC.SANTOS                               DOCAS
# DEIC - DEINTER 6                 JARDIM BOM RETIRO
#
#                                                             RUBRICA  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                     Roubo (art. 157)
# DEL.SEC.SANTOS                   Furto qualificado (art. 155, §4o.)
# DELEGACIA ELETRONICA                               Roubo (art. 157)
# DELEGACIA ELETRONICA                               Roubo (art. 157)
# DEL.SEC.SANTOS                      Furto de coisa comum (art. 156)
# ...                                                             ...
# DIV.POL.PORTO/AERO/PROT.TURISTA           Lesão corporal (art. 129)
# DELEGACIA ELETRONICA                               Roubo (art. 157)
# DELEGACIA ELETRONICA                               Roubo (art. 157)
# DEL.SEC.SANTOS                                     Roubo (art. 157)
# DEIC - DEINTER 6                     tráfico drogas (Art.33, caput)
#
#                                  MES_ESTATISTICA  ANO_ESTATISTICA
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                 1             2022
# DEL.SEC.SANTOS                                 1             2022
# DELEGACIA ELETRONICA                           1             2022
# DELEGACIA ELETRONICA                           1             2022
# DEL.SEC.SANTOS                                 1             2022
# ...                                          ...              ...
# DIV.POL.PORTO/AERO/PROT.TURISTA                6             2024
# DELEGACIA ELETRONICA                           6             2024
# DELEGACIA ELETRONICA                           6             2024
# DEL.SEC.SANTOS                                 6             2024
# DEIC - DEINTER 6                               6             2024
#
# [36200 rows x 10 columns]

# %%
# filtrando ocorrencias de estupro
# filtring the rape data

df_occ = df_city[(df_city['RUBRICA'].str.upper().str.contains("ESTUPRO", regex=False, na=False, case=False))]
df_occ
# Out:
#                      NOME_MUNICIPIO DATA_REGISTRO   DATA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE         SANTOS    2022-01-05  2021-11-20 00:00:00
# DEL.SEC.SANTOS               SANTOS    2022-01-09  2022-01-09 00:00:00
# DEL.SEC.SANTOS               SANTOS    2022-01-16  2022-01-15 00:00:00
# DEL.SEC.SANTOS               SANTOS    2022-01-11                  NaN
# DEL.SEC.SANTOS               SANTOS    2022-02-05  2021-10-17 00:00:00
# ...                             ...           ...                  ...
# DEL.SEC.SANTOS               SANTOS    2024-05-08           2024-05-01
# DEL.SEC.SANTOS               SANTOS    2024-05-15           2024-05-05
# DEL.SEC.SANTOS               SANTOS    2024-05-21           2024-05-21
# DEL.SEC.SANTOS               SANTOS    2024-05-21           2011-06-08
# DEL.SEC.SANTOS               SANTOS    2024-06-18           2024-06-17
#
#                      HORA_OCORRENCIA_BO     DESC_PERIODO    DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE           21:00:00              NaN  Comércio e Serviços
# DEL.SEC.SANTOS                 00:07:39              NaN           Residência
# DEL.SEC.SANTOS                 19:30:27              NaN           Residência
# DEL.SEC.SANTOS                      NaN  EM HORA INCERTA           Residência
# DEL.SEC.SANTOS                      NaN     DE MADRUGADA          Via Pública
# ...                                 ...              ...                  ...
# DEL.SEC.SANTOS                      NaN  Em hora incerta                 Casa
# DEL.SEC.SANTOS                 20:00:56              NaN                Casas
# DEL.SEC.SANTOS                 10:30:00              NaN          Via Pública
# DEL.SEC.SANTOS                      NaN       Pela manhã          Apartamento
# DEL.SEC.SANTOS                 20:10:00              NaN               Outros
#
#                                  BAIRRO                            RUBRICA  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE        VILA MATIAS                 Art. 213 - Estupro
# DEL.SEC.SANTOS                   MARAPE  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS                   MACUCO                 Art. 213 - Estupro
# DEL.SEC.SANTOS        MORRO NOVA CINTRA  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS                   MACUCO                 Art. 213 - Estupro
# ...                                 ...                                ...
# DEL.SEC.SANTOS              SANTA MARIA  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS              RADIO CLUBE  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS                  GONZAGA                 Art. 213 - Estupro
# DEL.SEC.SANTOS              JOSÉ MENINO                 Art. 213 - Estupro
# DEL.SEC.SANTOS              VILA MATIAS                 Estupro - Art. 213
#
#                       MES_ESTATISTICA  ANO_ESTATISTICA
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE                1             2022
# DEL.SEC.SANTOS                      1             2022
# DEL.SEC.SANTOS                      1             2022
# DEL.SEC.SANTOS                      1             2022
# DEL.SEC.SANTOS                      2             2022
# ...                               ...              ...
# DEL.SEC.SANTOS                      5             2024
# DEL.SEC.SANTOS                      5             2024
# DEL.SEC.SANTOS                      5             2024
# DEL.SEC.SANTOS                      5             2024
# DEL.SEC.SANTOS                      6             2024
#
# [218 rows x 10 columns]

# %% [markdown]
# # SAVE

# %%
df_occ.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\df_cleaned", index=False)
