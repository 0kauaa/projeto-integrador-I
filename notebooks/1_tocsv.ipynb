# %% [markdown]
# # LIBS

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# # IMPORT

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# dados de 2022
# 2022 data

path2022 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2022.xlsx"
first_semester_2022 = pd.read_excel(path2022, sheet_name=0)
second_semester_2022 = pd.read_excel(path2022, sheet_name=1)

# %%
# dados de 2023
# 2023 data

path2023 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2023.xlsx"
first_semester_2023 = pd.read_excel(path2023, sheet_name=0)
second_semester_2023 = pd.read_excel(path2023, sheet_name=1)

# %%
# dados de 2024
# 2024 data

path2024 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2024.xlsx"
first_semester_2024 = pd.read_excel(path2024, sheet_name=0)
second_semester_2024 = pd.read_excel(path2024, sheet_name=1)

# %%
# dados de 2025
# 2024 data

path2025 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2025.xlsx"
first_semester_2025 = pd.read_excel(path2025, sheet_name=0)
second_semester_2025 = pd.read_excel(path2025, sheet_name=1)

# %% [markdown]
# # SAVE

# %%
# csv é bem mais facil de manipular que xlsx, entao passo tudo para csv antes de começar a mexer nos dados em si
# csv is easier to manipulate than xlsx, so i convert everything to csv before to start manipulating the data itself

first_semester_2022.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2022.xlsx", index=False)
second_semester_2022.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2022.xlsx", index=False)

first_semester_2023.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2023.xlsx", index=False)
second_semester_2023.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2023.xlsx", index=False)

first_semester_2024.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2024.xlsx", index=False)
second_semester_2024.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2024.xlsx", index=False)

first_semester_2025.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2025.xlsx", index=False)
second_semester_2025.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2025.xlsx", index=False)
