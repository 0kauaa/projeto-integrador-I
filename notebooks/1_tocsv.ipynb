# %% [markdown]
# # LIBS

# %%
import pandas as pd

# %% [markdown]
# # IMPORT

# %%
# dados de 2022
# 2022 data

path2022 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\SPDadosCriminais_2022.xlsx"
first_semester_2022 = pd.read_excel(path2022, sheet_name=0)
second_semester_2022 = pd.read_excel(path2022, sheet_name=1)

# %%
# dados de 2023
# 2023 data

path2023 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\SPDadosCriminais_2023.xlsx"
first_semester_2023 = pd.read_excel(path2023, sheet_name=0)
second_semester_2023 = pd.read_excel(path2023, sheet_name=1)

# %%
# dados de 2024
# 2024 data

path2024 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\SPDadosCriminais_2024.xlsx"
first_semester_2024 = pd.read_excel(path2024, sheet_name=0)
second_semester_2024 = pd.read_excel(path2024, sheet_name=1)

# %%
# dados de 2025
# 2024 data

path2025 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\SPDadosCriminais_2025.xlsx"
first_semester_2025 = pd.read_excel(path2025, sheet_name=0)
second_semester_2025 = pd.read_excel(path2025, sheet_name=1)

# %% [markdown]
# # SAVE

# %%
# csv é bem mais facil de manipular que xlsx, entao passo tudo para csv antes de começar a mexer nos dados em si
# csv is easier to manipulate than xlsx, so i pass everything to csv before to start manipulating the data itself

first_semester_2022.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\1st_2022", index=False)
second_semester_2022.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\2nd_2022", index=False)

first_semester_2023.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\1st_2023", index=False)
second_semester_2023.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\2nd_2023", index=False)

first_semester_2024.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\1st_2024", index=False)
second_semester_2024.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\2nd_2024", index=False)

first_semester_2025.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\1st_2025", index=False)
second_semester_2025.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\PROJETO INTEGRADOR 1\\dados\\2nd_2025", index=False)
