# %% [markdown]
# # LIBS

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# # IMPORT

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# dados de 2022

first_path2022  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2022.xlsx"
second_path2022 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2022.xlsx"

first_df_2022  = pd.read_csv(first_path2022, index_col=0)
second_df_2022 = pd.read_csv(first_path2022, index_col=0)
# Out:
# /tmp/ipykernel_22391/653454469.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_df_2022  = pd.read_csv(first_path2022, index_col=0)
# /tmp/ipykernel_22391/653454469.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   second_df_2022 = pd.read_csv(first_path2022, index_col=0)

# %%
''' 
    em analise explorativa, notou-se que algumas colunas
    mantiveram suas features, mas foram renomeadas a partir
    de 2023, gerando uma incoerências do ano de 2022 com os
    restantes:
     
    cidade de ocorrencia deixou de ser nomeada como "CIDADE"
    e passou a ser nomeada como "NOME_MUNICIPIO";

    data de registro deixou de ser nemada como
    "DATA_COMUNICACAO_BO" e passou a ser nomeada
    como "DATA_REGISTRO";

    descrição de periodo de ocorrencia deicou de ser nomeada
    como "DESCR_PERIODO" e passou a ser nomeada como
    "DESC_PERIODO".

    descrição do local de ocorrencia deixou de ser nomeada
    como "DESCR_TIPOLOCAL e passou a ser nomeada como
    "DESCR_SUBTIPOLOCAL".
'''

# renomando as colunas de 2022
# renaming 2022 columns

first_df_2022_renamed  = first_df_2022.rename(columns={'CIDADE': 'NOME_MUNICIPIO',
                                                      'DATA_COMUNICACAO_BO': 'DATA_REGISTRO',
                                                      "DESCR_PERIODO": "DESC_PERIODO",
                                                      "DESCR_TIPOLOCAL": "DESCR_SUBTIPOLOCAL"})

second_df_2022_renamed = second_df_2022.rename(columns={'CIDADE': 'NOME_MUNICIPIO',
                                                      'DATA_COMUNICACAO_BO': 'DATA_REGISTRO',
                                                      "DESCR_PERIODO": "DESC_PERIODO",
                                                      "DESCR_TIPOLOCAL": "DESCR_SUBTIPOLOCAL"})

# %%
# dados de 2023

first_path2023  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2023.xlsx"
second_path2023 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2023.xlsx"

first_df_2023  = pd.read_csv(first_path2023, index_col=0)
second_df_2023 = pd.read_csv(first_path2023, index_col=0)
# Out:
# /tmp/ipykernel_22391/3622314882.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_df_2023  = pd.read_csv(first_path2023, index_col=0)
# /tmp/ipykernel_22391/3622314882.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   second_df_2023 = pd.read_csv(first_path2023, index_col=0)

# %%
# dados de 2024

first_path2024  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2024.xlsx"
second_path2024 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2024.xlsx"

first_df_2024  = pd.read_csv(first_path2024, index_col=0)
second_df_2024 = pd.read_csv(first_path2024, index_col=0)

# %%
# dados de 2025

first_path2025  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2025.xlsx"
second_path2025 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2025.xlsx"

first_df_2025  = pd.read_csv(first_path2025, index_col=0)
second_df_2025 = pd.read_csv(first_path2025, index_col=0)
# Out:
# /tmp/ipykernel_22391/3589937457.py:6: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_df_2025  = pd.read_csv(first_path2025, index_col=0)
# /tmp/ipykernel_22391/3589937457.py:7: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   second_df_2025 = pd.read_csv(first_path2025, index_col=0)

# %%
second_df_2025
# Out:
#                                         NOME_SECCIONAL  \
# NOME_DEPARTAMENTO
# DECAP                                DEL.SEC.1º CENTRO
# DECAP                                DEL.SEC.1º CENTRO
# DECAP                                DEL.SEC.1º CENTRO
# DECAP                           DEL.SEC.6º SANTO AMARO
# DIPOL - DEPTO DE INTELIGENCIA     DELEGACIA ELETRONICA
# ...                                                ...
# DEMACRO                        DEL.SEC.TABOÃO DA SERRA
# DEMACRO                        DEL.SEC.TABOÃO DA SERRA
# DEMACRO                        DEL.SEC.TABOÃO DA SERRA
# DEMACRO                        DEL.SEC.TABOÃO DA SERRA
# DEMACRO                        DEL.SEC.TABOÃO DA SERRA
#
#                                          NOME_DELEGACIA   NOME_MUNICIPIO  \
# NOME_DEPARTAMENTO
# DECAP                                    01ª DDM CENTRO          S.PAULO
# DECAP                                    01ª DDM CENTRO          S.PAULO
# DECAP                                    01ª DDM CENTRO          S.PAULO
# DECAP                               06ª DDM SANTO AMARO          S.PAULO
# DIPOL - DEPTO DE INTELIGENCIA    DELEGACIA ELETRONICA 1          S.PAULO
# ...                                                 ...              ...
# DEMACRO                        01º D.P. TABOÃO DA SERRA  TABOAO DA SERRA
# DEMACRO                        02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA
# DEMACRO                        01º D.P. TABOÃO DA SERRA  TABOAO DA SERRA
# DEMACRO                        02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA
# DEMACRO                         01º D.P. EMBU DAS ARTES   EMBU DAS ARTES
#
#                                NUM_BO  ANO_BO DATA_REGISTRO  \
# NOME_DEPARTAMENTO
# DECAP                          AA2328    2025    2025-01-01
# DECAP                          AM7136    2025    2025-01-10
# DECAP                          AQ9561    2025    2025-01-14
# DECAP                          BH3385    2025    2025-01-27
# DIPOL - DEPTO DE INTELIGENCIA  AA1448    2025    2025-01-01
# ...                               ...     ...           ...
# DEMACRO                        IO7458    2025    2025-06-12
# DEMACRO                        IU8903    2025    2025-06-17
# DEMACRO                        IX5583    2025    2025-06-19
# DEMACRO                        JC6010    2025    2025-06-24
# DEMACRO                        JF1547    2025    2025-06-26
#
#                               DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO  \
# NOME_DEPARTAMENTO
# DECAP                                 2024-12-31           18:00:00
# DECAP                                 2025-01-10           00:00:00
# DECAP                                 2025-01-14                NaN
# DECAP                                 2025-01-25           18:00:14
# DIPOL - DEPTO DE INTELIGENCIA         2024-12-31           10:30:00
# ...                                          ...                ...
# DEMACRO                               2025-06-12           19:00:00
# DEMACRO                               2025-06-17           16:00:00
# DEMACRO                               2025-06-19           14:00:00
# DEMACRO                               2025-06-24           11:00:59
# DEMACRO                               2025-06-26           09:50:00
#
#                                   DESC_PERIODO      DESCR_TIPOLOCAL  ...  \
# NOME_DEPARTAMENTO                                                    ...
# DECAP                                      NaN  Comércio e Serviços  ...
# DECAP                                      NaN          Via Pública  ...
# DECAP                          Em hora incerta           Residência  ...
# DECAP                                      NaN           Hospedagem  ...
# DIPOL - DEPTO DE INTELIGENCIA              NaN          Via Pública  ...
# ...                                        ...                  ...  ...
# DEMACRO                                    NaN          Via Pública  ...
# DEMACRO                                    NaN          Via Pública  ...
# DEMACRO                                    NaN          Via Pública  ...
# DEMACRO                                    NaN          Via Pública  ...
# DEMACRO                                    NaN          Via Pública  ...
#
#                               NOME_SECCIONAL_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DECAP                                    DEL.SEC.1º CENTRO
# DECAP                                    DEL.SEC.1º CENTRO
# DECAP                                    DEL.SEC.1º CENTRO
# DECAP                                    DEL.SEC.1º CENTRO
# DIPOL - DEPTO DE INTELIGENCIA            DEL.SEC.1º CENTRO
# ...                                                    ...
# DEMACRO                            DEL.SEC.TABOÃO DA SERRA
# DEMACRO                            DEL.SEC.TABOÃO DA SERRA
# DEMACRO                            DEL.SEC.TABOÃO DA SERRA
# DEMACRO                            DEL.SEC.TABOÃO DA SERRA
# DEMACRO                            DEL.SEC.TABOÃO DA SERRA
#
#                               NOME_MUNICIPIO_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DECAP                                              S.PAULO
# DECAP                                              S.PAULO
# DECAP                                              S.PAULO
# DECAP                                              S.PAULO
# DIPOL - DEPTO DE INTELIGENCIA                      S.PAULO
# ...                                                    ...
# DEMACRO                                    TABOAO DA SERRA
# DEMACRO                                    TABOAO DA SERRA
# DEMACRO                                    TABOAO DA SERRA
# DEMACRO                                    TABOAO DA SERRA
# DEMACRO                                    TABOAO DA SERRA
#
#                                                          RUBRICA  \
# NOME_DEPARTAMENTO
# DECAP                          Estupro de vulneravel (art.217-A)
# DECAP                          Estupro de vulneravel (art.217-A)
# DECAP                          Estupro de vulneravel (art.217-A)
# DECAP                          Estupro de vulneravel (art.217-A)
# DIPOL - DEPTO DE INTELIGENCIA                   Furto (art. 155)
# ...                                                          ...
# DEMACRO                           tráfico drogas (Art.33, caput)
# DEMACRO                           tráfico drogas (Art.33, caput)
# DEMACRO                           tráfico drogas (Art.33, caput)
# DEMACRO                           tráfico drogas (Art.33, caput)
# DEMACRO                           tráfico drogas (Art.33, caput)
#
#                                DESCR_CONDUTA          NATUREZA_APURADA  \
# NOME_DEPARTAMENTO
# DECAP                                    NaN     ESTUPRO DE VULNERÁVEL
# DECAP                                    NaN     ESTUPRO DE VULNERÁVEL
# DECAP                                    NaN     ESTUPRO DE VULNERÁVEL
# DECAP                                    NaN     ESTUPRO DE VULNERÁVEL
# DIPOL - DEPTO DE INTELIGENCIA         Outros            FURTO - OUTROS
# ...                                      ...                       ...
# DEMACRO                                  NaN  TRÁFICO DE ENTORPECENTES
# DEMACRO                                  NaN  TRÁFICO DE ENTORPECENTES
# DEMACRO                                  NaN  TRÁFICO DE ENTORPECENTES
# DEMACRO                                  NaN  TRÁFICO DE ENTORPECENTES
# DEMACRO                                  NaN  TRÁFICO DE ENTORPECENTES
#
#                               MES_ESTATISTICA ANO_ESTATISTICA     CMD  \
# NOME_DEPARTAMENTO
# DECAP                                       1            2025  CPA/M1
# DECAP                                       1            2025  CPA/M1
# DECAP                                       1            2025  CPA/M1
# DECAP                                       1            2025  CPA/M1
# DIPOL - DEPTO DE INTELIGENCIA               1            2025  CPA/M1
# ...                                       ...             ...     ...
# DEMACRO                                     6            2025  CPA/M8
# DEMACRO                                     6            2025  CPA/M8
# DEMACRO                                     6            2025  CPA/M8
# DEMACRO                                     6            2025  CPA/M8
# DEMACRO                                     6            2025  CPA/M8
#
#                                     BTL          CIA
# NOME_DEPARTAMENTO
# DECAP                           7ºBPM/M  3ªCIA 4ªCIA
# DECAP                           7ºBPM/M  3ªCIA 4ªCIA
# DECAP                           7ºBPM/M  3ªCIA 4ªCIA
# DECAP                           7ºBPM/M  3ªCIA 4ªCIA
# DIPOL - DEPTO DE INTELIGENCIA   7ºBPM/M  3ªCIA 4ªCIA
# ...                                 ...          ...
# DEMACRO                        36ºBPM/M        2ªCIA
# DEMACRO                        36ºBPM/M        2ªCIA
# DEMACRO                        36ºBPM/M        2ªCIA
# DEMACRO                        36ºBPM/M        2ªCIA
# DEMACRO                        36ºBPM/M        2ªCIA
#
# [585427 rows x 28 columns]

# %%
# o ano de 2025 tem 3 colunas a mais (cmd, ctl, cia)
df2025 = pd.concat([first_df_2025, second_df_2025], axis=0)
df2025 = df2025.drop(columns=['CMD', 'BTL', 'CIA'], axis=1) # remover para o merge
df2025.tail()
# Out:
#                             NOME_SECCIONAL            NOME_DELEGACIA  \
# NOME_DEPARTAMENTO
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA   01º D.P. EMBU DAS ARTES
#
#                     NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO  \
# NOME_DEPARTAMENTO
# DEMACRO            TABOAO DA SERRA  IO7458    2025    2025-06-12
# DEMACRO            TABOAO DA SERRA  IU8903    2025    2025-06-17
# DEMACRO            TABOAO DA SERRA  IX5583    2025    2025-06-19
# DEMACRO            TABOAO DA SERRA  JC6010    2025    2025-06-24
# DEMACRO             EMBU DAS ARTES  JF1547    2025    2025-06-26
#
#                   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO DESC_PERIODO  \
# NOME_DEPARTAMENTO
# DEMACRO                   2025-06-12           19:00:00          NaN
# DEMACRO                   2025-06-17           16:00:00          NaN
# DEMACRO                   2025-06-19           14:00:00          NaN
# DEMACRO                   2025-06-24           11:00:59          NaN
# DEMACRO                   2025-06-26           09:50:00          NaN
#
#                   DESCR_TIPOLOCAL  ...  LONGITUDE  \
# NOME_DEPARTAMENTO                  ...
# DEMACRO               Via Pública  ... -46.786183
# DEMACRO               Via Pública  ... -46.797775
# DEMACRO               Via Pública  ... -46.796994
# DEMACRO               Via Pública  ... -46.788974
# DEMACRO               Via Pública  ... -46.804309
#
#                   NOME_DELEGACIA_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
#
#                   NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
#
#                    NOME_SECCIONAL_CIRCUNSCRICAO NOME_MUNICIPIO_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
#
#                                           RUBRICA DESCR_CONDUTA  \
# NOME_DEPARTAMENTO
# DEMACRO            tráfico drogas (Art.33, caput)           NaN
# DEMACRO            tráfico drogas (Art.33, caput)           NaN
# DEMACRO            tráfico drogas (Art.33, caput)           NaN
# DEMACRO            tráfico drogas (Art.33, caput)           NaN
# DEMACRO            tráfico drogas (Art.33, caput)           NaN
#
#                            NATUREZA_APURADA MES_ESTATISTICA ANO_ESTATISTICA
# NOME_DEPARTAMENTO
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2025
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2025
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2025
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2025
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2025
#
# [5 rows x 25 columns]

# %%
first_df_2025['DESCR_TIPOLOCAL']
# Out:
# NOME_DEPARTAMENTO
# DECAP                            Comércio e Serviços
# DECAP                                    Via Pública
# DECAP                                     Residência
# DECAP                                     Hospedagem
# DIPOL - DEPTO DE INTELIGENCIA            Via Pública
#                                         ...
# DEMACRO                                  Via Pública
# DEMACRO                                  Via Pública
# DEMACRO                                  Via Pública
# DEMACRO                                  Via Pública
# DEMACRO                                  Via Pública
# Name: DESCR_TIPOLOCAL, Length: 585427, dtype: object

# %%
first_df_2025['DESCR_SUBTIPOLOCAL']
# Out:
# NOME_DEPARTAMENTO
# DECAP                                Mercado
# DECAP                            Via Pública
# DECAP                                   Casa
# DECAP                                  Motel
# DIPOL - DEPTO DE INTELIGENCIA    Via Pública
#                                     ...
# DEMACRO                          Via Pública
# DEMACRO                          Via Pública
# DEMACRO                          Via Pública
# DEMACRO                          Via Pública
# DEMACRO                          Via Pública
# Name: DESCR_SUBTIPOLOCAL, Length: 585427, dtype: object

# %%
print(len(first_df_2024.columns), len(df2025.columns))
# Out:
# 24 25

# %% [markdown]
# # MERGE

# %%
# junção dos dados

list_df = [first_df_2022_renamed, second_df_2022_renamed, 
           first_df_2023, second_df_2023, 
           df2025]

df_merged = pd.concat(list_df, axis=0)
df_merged.tail()
# Out:
#                             NOME_SECCIONAL            NOME_DELEGACIA  \
# NOME_DEPARTAMENTO
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA   01º D.P. EMBU DAS ARTES
#
#                     NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO  \
# NOME_DEPARTAMENTO
# DEMACRO            TABOAO DA SERRA  IO7458    2025    2025-06-12
# DEMACRO            TABOAO DA SERRA  IU8903    2025    2025-06-17
# DEMACRO            TABOAO DA SERRA  IX5583    2025    2025-06-19
# DEMACRO            TABOAO DA SERRA  JC6010    2025    2025-06-24
# DEMACRO             EMBU DAS ARTES  JF1547    2025    2025-06-26
#
#                   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO DESC_PERIODO  \
# NOME_DEPARTAMENTO
# DEMACRO                   2025-06-12           19:00:00          NaN
# DEMACRO                   2025-06-17           16:00:00          NaN
# DEMACRO                   2025-06-19           14:00:00          NaN
# DEMACRO                   2025-06-24           11:00:59          NaN
# DEMACRO                   2025-06-26           09:50:00          NaN
#
#                   DESCR_SUBTIPOLOCAL  ...                         RUBRICA  \
# NOME_DEPARTAMENTO                     ...
# DEMACRO                  Via Pública  ...  tráfico drogas (Art.33, caput)
# DEMACRO                  Via Pública  ...  tráfico drogas (Art.33, caput)
# DEMACRO                  Via Pública  ...  tráfico drogas (Art.33, caput)
# DEMACRO                  Via Pública  ...  tráfico drogas (Art.33, caput)
# DEMACRO                  Via Pública  ...  tráfico drogas (Art.33, caput)
#
#                   DESCR_CONDUTA          NATUREZA_APURADA MES_ESTATISTICA  \
# NOME_DEPARTAMENTO
# DEMACRO                     NaN  TRÁFICO DE ENTORPECENTES               6
# DEMACRO                     NaN  TRÁFICO DE ENTORPECENTES               6
# DEMACRO                     NaN  TRÁFICO DE ENTORPECENTES               6
# DEMACRO                     NaN  TRÁFICO DE ENTORPECENTES               6
# DEMACRO                     NaN  TRÁFICO DE ENTORPECENTES               6
#
#                   ANO_ESTATISTICA DESCR_TIPOLOCAL  \
# NOME_DEPARTAMENTO
# DEMACRO                      2025     Via Pública
# DEMACRO                      2025     Via Pública
# DEMACRO                      2025     Via Pública
# DEMACRO                      2025     Via Pública
# DEMACRO                      2025     Via Pública
#
#                   NOME_DELEGACIA_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
#
#                   NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# NOME_DEPARTAMENTO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
#
#                   NOME_SECCIONAL_CIRCUNSCRICAO NOME_MUNICIPIO_CIRCUNSCRICAO
# NOME_DEPARTAMENTO
# DEMACRO                DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEMACRO                DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
#
# [5 rows x 29 columns]

# %%
# normalizando "desc"

df = df_merged.rename(columns={'DESCR_SUBTIPOLOCAL': 'DESC_SUBTIPOLOCAL'})
df
# Out:
#                             NOME_SECCIONAL            NOME_DELEGACIA  \
# NOME_DEPARTAMENTO
# DECAP                DEL.SEC.8º SAO MATEUS        08ª DDM SAO MATEUS
# DECAP                DEL.SEC.8º SAO MATEUS  54º D.P. CID. TIRADENTES
# DECAP                     DEL.SEC.5º LESTE    29º D.P. VILA PRUDENTE
# DECAP                    DEL.SEC.1º CENTRO               01º D.P. SE
# DECAP                    DEL.SEC.1º CENTRO          06º D.P. CAMBUCI
# ...                                    ...                       ...
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA
#
#                     NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO  \
# NOME_DEPARTAMENTO
# DECAP                      S.PAULO  AC0851    2022    2022-01-13
# DECAP                      S.PAULO       4    2022    2022-01-03
# DECAP                      S.PAULO       7    2022    2022-01-04
# DECAP                      S.PAULO       8    2022    2022-01-03
# DECAP                      S.PAULO       8    2022    2022-01-03
# ...                            ...     ...     ...           ...
# DEMACRO            TABOAO DA SERRA  IR7765    2024    2024-06-25
# DEMACRO            TABOAO DA SERRA  IS4320    2024    2024-06-26
# DEMACRO            TABOAO DA SERRA  IU0529    2024    2024-06-27
# DEMACRO            TABOAO DA SERRA  IU3825    2024    2024-06-27
# DEMACRO            TABOAO DA SERRA  IU8115    2024    2024-06-27
#
#                     DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO     DESC_PERIODO  \
# NOME_DEPARTAMENTO
# DECAP              2021-09-01 00:00:00                NaN  EM HORA INCERTA
# DECAP              2021-12-31 00:00:00           15:20:00              NaN
# DECAP              2021-12-30 00:00:00                NaN  EM HORA INCERTA
# DECAP              2022-01-03 00:00:00           16:00:00              NaN
# DECAP              2022-01-03 00:00:00           13:30:00              NaN
# ...                                ...                ...              ...
# DEMACRO                     2024-06-25           12:58:42              NaN
# DEMACRO                     2024-06-25           20:40:00              NaN
# DEMACRO                     2024-06-27           03:13:00              NaN
# DEMACRO                     2024-06-27           09:40:00              NaN
# DEMACRO                     2024-06-27           13:27:44              NaN
#
#                   DESC_SUBTIPOLOCAL  ...  LONGITUDE  \
# NOME_DEPARTAMENTO                    ...
# DECAP                    Residência  ...   0.000000
# DECAP                   Via pública  ... -46.632520
# DECAP              Terminal/Estação  ... -46.631091
# DECAP                   Via pública  ... -46.625872
# DECAP                   Via pública  ... -46.630224
# ...                             ...  ...        ...
# DEMACRO                 Via Pública  ... -46.795586
# DEMACRO                 Via Pública  ... -46.788974
# DEMACRO                 Via Pública  ... -46.794137
# DEMACRO                 Via Pública  ... -46.789868
# DEMACRO                 Via Pública  ... -46.805860
#
#                   NOME_DELEGACIA_CIRCUNSCRIÇÃO  \
# NOME_DEPARTAMENTO
# DECAP                              01º D.P. SE
# DECAP                              01º D.P. SE
# DECAP                              01º D.P. SE
# DECAP                              01º D.P. SE
# DECAP                              01º D.P. SE
# ...                                        ...
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
# DEMACRO               02º D.P. TABOÃO DA SERRA
#
#                   NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO  \
# NOME_DEPARTAMENTO
# DECAP                                       DECAP
# DECAP                                       DECAP
# DECAP                                       DECAP
# DECAP                                       DECAP
# DECAP                                       DECAP
# ...                                           ...
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
# DEMACRO                                   DEMACRO
#
#                    NOME_SECCIONAL_CIRCUNSCRIÇÃO  NOME_MUNICIPIO_CIRCUNSCRIÇÃO  \
# NOME_DEPARTAMENTO
# DECAP                         DEL.SEC.1º CENTRO                       S.PAULO
# DECAP                         DEL.SEC.1º CENTRO                       S.PAULO
# DECAP                         DEL.SEC.1º CENTRO                       S.PAULO
# DECAP                         DEL.SEC.1º CENTRO                       S.PAULO
# DECAP                         DEL.SEC.1º CENTRO                       S.PAULO
# ...                                         ...                           ...
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA               TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA               TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA               TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA               TABOAO DA SERRA
# DEMACRO                 DEL.SEC.TABOÃO DA SERRA               TABOAO DA SERRA
#
#                                           RUBRICA        DESCR_CONDUTA  \
# NOME_DEPARTAMENTO
# DECAP                          Art. 213 - Estupro                  NaN
# DECAP                            Furto (art. 155)  INTERIOR DE VEICULO
# DECAP                            Furto (art. 155)           TRANSEUNTE
# DECAP                            Furto (art. 155)  INTERIOR DE VEICULO
# DECAP                            Furto (art. 155)  INTERIOR DE VEICULO
# ...                                           ...                  ...
# DEMACRO            tráfico drogas (Art.33, caput)                  NaN
# DEMACRO            tráfico drogas (Art.33, caput)                  NaN
# DEMACRO            tráfico drogas (Art.33, caput)                  NaN
# DEMACRO            tráfico drogas (Art.33, caput)                  NaN
# DEMACRO            tráfico drogas (Art.33, caput)                  NaN
#
#                            NATUREZA_APURADA MES_ESTATISTICA ANO_ESTATISTICA
# NOME_DEPARTAMENTO
# DECAP                               ESTUPRO               1            2022
# DECAP                        FURTO - OUTROS               1            2022
# DECAP                        FURTO - OUTROS               1            2022
# DECAP                        FURTO - OUTROS               1            2022
# DECAP                        FURTO - OUTROS               1            2022
# ...                                     ...             ...             ...
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2024
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2024
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2024
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2024
# DEMACRO            TRÁFICO DE ENTORPECENTES               6            2024
#
# [4774356 rows x 24 columns]

# %% [markdown]
# # SAVE

# %%
df.to_csv("/content/drive/My Drive/projeto-integrador-I/data/processed/df_merged.csv", index=False)
