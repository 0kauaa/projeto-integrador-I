# %% [markdown]
# # libs

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# # import dos dados

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df_path = "/content/drive/My Drive/projeto-integrador-I/data/processed/df_merged.csv"
df = pd.read_csv(df_path, index_col=0)

df
# Out:
# /tmp/ipykernel_24486/1294664248.py:2: DtypeWarning: Columns (12,13,14,15,16,17,18,24,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(df_path, index_col=0)
#                                    NOME_DELEGACIA   NOME_MUNICIPIO  NUM_BO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS          08ª DDM SAO MATEUS          S.PAULO  AC0851
# DEL.SEC.8º SAO MATEUS    54º D.P. CID. TIRADENTES          S.PAULO       4
# DEL.SEC.5º LESTE           29º D.P. VILA PRUDENTE          S.PAULO       7
# DEL.SEC.1º CENTRO                     01º D.P. SE          S.PAULO       8
# DEL.SEC.1º CENTRO                06º D.P. CAMBUCI          S.PAULO       8
# ...                                           ...              ...     ...
# DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IO7458
# DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IU8903
# DEL.SEC.TABOÃO DA SERRA  01º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  IX5583
# DEL.SEC.TABOÃO DA SERRA  02º D.P. TABOÃO DA SERRA  TABOAO DA SERRA  JC6010
# DEL.SEC.TABOÃO DA SERRA   01º D.P. EMBU DAS ARTES   EMBU DAS ARTES  JF1547
#
#                          ANO_BO DATA_REGISTRO   DATA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS      2022    2022-01-13  2021-09-01 00:00:00
# DEL.SEC.8º SAO MATEUS      2022    2022-01-03  2021-12-31 00:00:00
# DEL.SEC.5º LESTE           2022    2022-01-04  2021-12-30 00:00:00
# DEL.SEC.1º CENTRO          2022    2022-01-03  2022-01-03 00:00:00
# DEL.SEC.1º CENTRO          2022    2022-01-03  2022-01-03 00:00:00
# ...                         ...           ...                  ...
# DEL.SEC.TABOÃO DA SERRA    2025    2025-06-12           2025-06-12
# DEL.SEC.TABOÃO DA SERRA    2025    2025-06-17           2025-06-17
# DEL.SEC.TABOÃO DA SERRA    2025    2025-06-19           2025-06-19
# DEL.SEC.TABOÃO DA SERRA    2025    2025-06-24           2025-06-24
# DEL.SEC.TABOÃO DA SERRA    2025    2025-06-26           2025-06-26
#
#                         HORA_OCORRENCIA_BO     DESC_PERIODO DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                  NaN  EM HORA INCERTA        Residência
# DEL.SEC.8º SAO MATEUS             15:20:00              NaN       Via pública
# DEL.SEC.5º LESTE                       NaN  EM HORA INCERTA  Terminal/Estação
# DEL.SEC.1º CENTRO                 16:00:00              NaN       Via pública
# DEL.SEC.1º CENTRO                 13:30:00              NaN       Via pública
# ...                                    ...              ...               ...
# DEL.SEC.TABOÃO DA SERRA           19:00:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           16:00:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           14:00:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           11:00:59              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           09:50:00              NaN       Via Pública
#
#                                                 BAIRRO  ...  \
# NOME_SECCIONAL                                          ...
# DEL.SEC.8º SAO MATEUS                               SE  ...
# DEL.SEC.8º SAO MATEUS    Centro Histórico de São Paulo  ...
# DEL.SEC.5º LESTE                                    SE  ...
# DEL.SEC.1º CENTRO                            Liberdade  ...
# DEL.SEC.1º CENTRO                            LIBERDADE  ...
# ...                                                ...  ...
# DEL.SEC.TABOÃO DA SERRA                JARDIM SAPORITO  ...
# DEL.SEC.TABOÃO DA SERRA                   J FREITAS JR  ...
# DEL.SEC.TABOÃO DA SERRA          JARDIM FREITAS JUNIOR  ...
# DEL.SEC.TABOÃO DA SERRA                   J S SALVADOR  ...
# DEL.SEC.TABOÃO DA SERRA                    P JACARANDA  ...
#
#                         NOME_MUNICIPIO_CIRCUNSCRIÇÃO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                        S.PAULO
# DEL.SEC.8º SAO MATEUS                        S.PAULO
# DEL.SEC.5º LESTE                             S.PAULO
# DEL.SEC.1º CENTRO                            S.PAULO
# DEL.SEC.1º CENTRO                            S.PAULO
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA                          NaN
# DEL.SEC.TABOÃO DA SERRA                          NaN
# DEL.SEC.TABOÃO DA SERRA                          NaN
# DEL.SEC.TABOÃO DA SERRA                          NaN
# DEL.SEC.TABOÃO DA SERRA                          NaN
#
#                                                 RUBRICA        DESCR_CONDUTA  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                Art. 213 - Estupro                  NaN
# DEL.SEC.8º SAO MATEUS                  Furto (art. 155)  INTERIOR DE VEICULO
# DEL.SEC.5º LESTE                       Furto (art. 155)           TRANSEUNTE
# DEL.SEC.1º CENTRO                      Furto (art. 155)  INTERIOR DE VEICULO
# DEL.SEC.1º CENTRO                      Furto (art. 155)  INTERIOR DE VEICULO
# ...                                                 ...                  ...
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                  NaN
#
#                                  NATUREZA_APURADA MES_ESTATISTICA  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                     ESTUPRO               1
# DEL.SEC.8º SAO MATEUS              FURTO - OUTROS               1
# DEL.SEC.5º LESTE                   FURTO - OUTROS               1
# DEL.SEC.1º CENTRO                  FURTO - OUTROS               1
# DEL.SEC.1º CENTRO                  FURTO - OUTROS               1
# ...                                           ...             ...
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
# DEL.SEC.TABOÃO DA SERRA  TRÁFICO DE ENTORPECENTES               6
#
#                         ANO_ESTATISTICA NOME_DELEGACIA_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS              2022                          NaN
# DEL.SEC.8º SAO MATEUS              2022                          NaN
# DEL.SEC.5º LESTE                   2022                          NaN
# DEL.SEC.1º CENTRO                  2022                          NaN
# DEL.SEC.1º CENTRO                  2022                          NaN
# ...                                 ...                          ...
# DEL.SEC.TABOÃO DA SERRA            2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA            2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA            2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA            2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA            2025     02º D.P. TABOÃO DA SERRA
#
#                         NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                               NaN
# DEL.SEC.8º SAO MATEUS                               NaN
# DEL.SEC.5º LESTE                                    NaN
# DEL.SEC.1º CENTRO                                   NaN
# DEL.SEC.1º CENTRO                                   NaN
# ...                                                 ...
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
#
#                         NOME_SECCIONAL_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.5º LESTE                                 NaN
# DEL.SEC.1º CENTRO                                NaN
# DEL.SEC.1º CENTRO                                NaN
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
#
#                         NOME_MUNICIPIO_CIRCUNSCRICAO
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.5º LESTE                                 NaN
# DEL.SEC.1º CENTRO                                NaN
# DEL.SEC.1º CENTRO                                NaN
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
#
# [3575646 rows x 27 columns]

# %% [markdown]
# # limpeza

# %%
# exluindo colunas desnescessárias para o estudo

del_columns = [
    'NOME_DEPARTAMENTO', 
    'LATITUDE', 
    'NOME_SECCIONAL', 
    'LONGITUDE', 
    'NOME_DELEGACIA', 
    'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 
    'NUM_BO', 
    'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO',
    'ANO_BO', 
    'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 
    'LOGRADOURO', 
    'NOME_MUNICIPIO_CIRCUNSCRIÇÃO', 
    'NUMERO_LOGRADOURO', 
    'DESCR_CONDUTA',
    'NATUREZA_APURADA'
]

df_col = df.drop(columns=[col for col in del_columns if col in df.columns])
df_col
# Out:
#                           NOME_MUNICIPIO DATA_REGISTRO   DATA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS            S.PAULO    2022-01-13  2021-09-01 00:00:00
# DEL.SEC.8º SAO MATEUS            S.PAULO    2022-01-03  2021-12-31 00:00:00
# DEL.SEC.5º LESTE                 S.PAULO    2022-01-04  2021-12-30 00:00:00
# DEL.SEC.1º CENTRO                S.PAULO    2022-01-03  2022-01-03 00:00:00
# DEL.SEC.1º CENTRO                S.PAULO    2022-01-03  2022-01-03 00:00:00
# ...                                  ...           ...                  ...
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2025-06-12           2025-06-12
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2025-06-17           2025-06-17
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2025-06-19           2025-06-19
# DEL.SEC.TABOÃO DA SERRA  TABOAO DA SERRA    2025-06-24           2025-06-24
# DEL.SEC.TABOÃO DA SERRA   EMBU DAS ARTES    2025-06-26           2025-06-26
#
#                         HORA_OCORRENCIA_BO     DESC_PERIODO DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                  NaN  EM HORA INCERTA        Residência
# DEL.SEC.8º SAO MATEUS             15:20:00              NaN       Via pública
# DEL.SEC.5º LESTE                       NaN  EM HORA INCERTA  Terminal/Estação
# DEL.SEC.1º CENTRO                 16:00:00              NaN       Via pública
# DEL.SEC.1º CENTRO                 13:30:00              NaN       Via pública
# ...                                    ...              ...               ...
# DEL.SEC.TABOÃO DA SERRA           19:00:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           16:00:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           14:00:00              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           11:00:59              NaN       Via Pública
# DEL.SEC.TABOÃO DA SERRA           09:50:00              NaN       Via Pública
#
#                                                 BAIRRO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                               SE
# DEL.SEC.8º SAO MATEUS    Centro Histórico de São Paulo
# DEL.SEC.5º LESTE                                    SE
# DEL.SEC.1º CENTRO                            Liberdade
# DEL.SEC.1º CENTRO                            LIBERDADE
# ...                                                ...
# DEL.SEC.TABOÃO DA SERRA                JARDIM SAPORITO
# DEL.SEC.TABOÃO DA SERRA                   J FREITAS JR
# DEL.SEC.TABOÃO DA SERRA          JARDIM FREITAS JUNIOR
# DEL.SEC.TABOÃO DA SERRA                   J S SALVADOR
# DEL.SEC.TABOÃO DA SERRA                    P JACARANDA
#
#                                                 RUBRICA  MES_ESTATISTICA  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                Art. 213 - Estupro                1
# DEL.SEC.8º SAO MATEUS                  Furto (art. 155)                1
# DEL.SEC.5º LESTE                       Furto (art. 155)                1
# DEL.SEC.1º CENTRO                      Furto (art. 155)                1
# DEL.SEC.1º CENTRO                      Furto (art. 155)                1
# ...                                                 ...              ...
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
# DEL.SEC.TABOÃO DA SERRA  tráfico drogas (Art.33, caput)                6
#
#                          ANO_ESTATISTICA NOME_DELEGACIA_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS               2022                          NaN
# DEL.SEC.8º SAO MATEUS               2022                          NaN
# DEL.SEC.5º LESTE                    2022                          NaN
# DEL.SEC.1º CENTRO                   2022                          NaN
# DEL.SEC.1º CENTRO                   2022                          NaN
# ...                                  ...                          ...
# DEL.SEC.TABOÃO DA SERRA             2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA             2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA             2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA             2025     02º D.P. TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA             2025     02º D.P. TABOÃO DA SERRA
#
#                         NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                               NaN
# DEL.SEC.8º SAO MATEUS                               NaN
# DEL.SEC.5º LESTE                                    NaN
# DEL.SEC.1º CENTRO                                   NaN
# DEL.SEC.1º CENTRO                                   NaN
# ...                                                 ...
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
# DEL.SEC.TABOÃO DA SERRA                         DEMACRO
#
#                         NOME_SECCIONAL_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.5º LESTE                                 NaN
# DEL.SEC.1º CENTRO                                NaN
# DEL.SEC.1º CENTRO                                NaN
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
# DEL.SEC.TABOÃO DA SERRA      DEL.SEC.TABOÃO DA SERRA
#
#                         NOME_MUNICIPIO_CIRCUNSCRICAO
# NOME_SECCIONAL
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.8º SAO MATEUS                            NaN
# DEL.SEC.5º LESTE                                 NaN
# DEL.SEC.1º CENTRO                                NaN
# DEL.SEC.1º CENTRO                                NaN
# ...                                              ...
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
# DEL.SEC.TABOÃO DA SERRA              TABOAO DA SERRA
#
# [3575646 rows x 14 columns]

# %%
# filtrando os dados de santos

def city_filter(df, col, city):
    df[col] = df[col].str.strip().str.upper()

    return df[df[col] == city]

df_city = city_filter(df_col, "NOME_MUNICIPIO", "SANTOS")

df_city
# Out:
#                                 NOME_MUNICIPIO DATA_REGISTRO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                          SANTOS    2022-01-16
# DEL.SEC.SANTOS                          SANTOS    2022-01-11
# DELEGACIA ELETRONICA                    SANTOS    2022-01-13
# DELEGACIA ELETRONICA                    SANTOS    2022-01-19
# DEL.SEC.SANTOS                          SANTOS    2022-01-06
# ...                                        ...           ...
# DELEGACIA ELETRONICA                    SANTOS    2025-06-19
# DIV.POL.PORTO/AERO/PROT.TURISTA         SANTOS    2025-06-24
# DELEGACIA ELETRONICA                    SANTOS    2025-06-24
# DELEGACIA ELETRONICA                    SANTOS    2025-06-26
# DEL.SEC.PRAIA GRANDE                    SANTOS    2025-06-18
#
#                                   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                   2022-01-16 00:00:00           13:00:00
# DEL.SEC.SANTOS                   2021-12-19 00:00:00           22:40:00
# DELEGACIA ELETRONICA             2022-01-12 00:00:00           17:40:00
# DELEGACIA ELETRONICA             2021-12-07 00:00:00           10:15:00
# DEL.SEC.SANTOS                   2022-01-06 00:00:00                NaN
# ...                                              ...                ...
# DELEGACIA ELETRONICA                      2025-06-06                NaN
# DIV.POL.PORTO/AERO/PROT.TURISTA           2025-06-21           12:00:00
# DELEGACIA ELETRONICA                      2025-06-23           18:20:00
# DELEGACIA ELETRONICA                      2025-06-25           11:40:00
# DEL.SEC.PRAIA GRANDE                      2025-06-18           01:11:00
#
#                                 DESC_PERIODO DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                           NaN       Via pública
# DEL.SEC.SANTOS                           NaN          Internet
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DEL.SEC.SANTOS                    PELA MANHÃ       Via pública
# ...                                      ...               ...
# DELEGACIA ELETRONICA                 A noite            Outros
# DIV.POL.PORTO/AERO/PROT.TURISTA          NaN         Portuário
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DELEGACIA ELETRONICA                     NaN       Via Pública
# DEL.SEC.PRAIA GRANDE                     NaN       Via Pública
#
#                                             BAIRRO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                   VILA JOQUEI CLUBE
# DEL.SEC.SANTOS                           BOA VISTA
# DELEGACIA ELETRONICA                        ALEMOA
# DELEGACIA ELETRONICA                        ALEMOA
# DEL.SEC.SANTOS                              CENTRO
# ...                                            ...
# DELEGACIA ELETRONICA                   OUTEIRINHOS
# DIV.POL.PORTO/AERO/PROT.TURISTA        OUTEIRINHOS
# DELEGACIA ELETRONICA                 PORTO PAQUETA
# DELEGACIA ELETRONICA                   OUTEIRINHOS
# DEL.SEC.PRAIA GRANDE                        CENTRO
#
#                                                                            RUBRICA  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                                    Roubo (art. 157)
# DEL.SEC.SANTOS                                  Furto qualificado (art. 155, §4o.)
# DELEGACIA ELETRONICA                                              Roubo (art. 157)
# DELEGACIA ELETRONICA                                              Roubo (art. 157)
# DEL.SEC.SANTOS                                     Furto de coisa comum (art. 156)
# ...                                                                            ...
# DELEGACIA ELETRONICA                                              Furto (art. 155)
# DIV.POL.PORTO/AERO/PROT.TURISTA                                   Furto (art. 155)
# DELEGACIA ELETRONICA             Lesão corporal culposa na direção de veículo a...
# DELEGACIA ELETRONICA                                              Roubo (art. 157)
# DEL.SEC.PRAIA GRANDE                                              Roubo (art. 157)
#
#                                  MES_ESTATISTICA  ANO_ESTATISTICA  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                 1             2022
# DEL.SEC.SANTOS                                 1             2022
# DELEGACIA ELETRONICA                           1             2022
# DELEGACIA ELETRONICA                           1             2022
# DEL.SEC.SANTOS                                 1             2022
# ...                                          ...              ...
# DELEGACIA ELETRONICA                           6             2025
# DIV.POL.PORTO/AERO/PROT.TURISTA                6             2025
# DELEGACIA ELETRONICA                           6             2025
# DELEGACIA ELETRONICA                           6             2025
# DEL.SEC.PRAIA GRANDE                           6             2025
#
#                                   NOME_DELEGACIA_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                             NaN
# DEL.SEC.SANTOS                                             NaN
# DELEGACIA ELETRONICA                                       NaN
# DELEGACIA ELETRONICA                                       NaN
# DEL.SEC.SANTOS                                             NaN
# ...                                                        ...
# DELEGACIA ELETRONICA             DOPE - 05ª DP PORTO DE SANTOS
# DIV.POL.PORTO/AERO/PROT.TURISTA  DOPE - 05ª DP PORTO DE SANTOS
# DELEGACIA ELETRONICA             DOPE - 05ª DP PORTO DE SANTOS
# DELEGACIA ELETRONICA             DOPE - 05ª DP PORTO DE SANTOS
# DEL.SEC.PRAIA GRANDE             DOPE - 05ª DP PORTO DE SANTOS
#
#                                 NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                              NaN
# DEL.SEC.SANTOS                                              NaN
# DELEGACIA ELETRONICA                                        NaN
# DELEGACIA ELETRONICA                                        NaN
# DEL.SEC.SANTOS                                              NaN
# ...                                                         ...
# DELEGACIA ELETRONICA                         DEINTER 6 - SANTOS
# DIV.POL.PORTO/AERO/PROT.TURISTA              DEINTER 6 - SANTOS
# DELEGACIA ELETRONICA                         DEINTER 6 - SANTOS
# DELEGACIA ELETRONICA                         DEINTER 6 - SANTOS
# DEL.SEC.PRAIA GRANDE                         DEINTER 6 - SANTOS
#
#                                 NOME_SECCIONAL_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                           NaN
# DEL.SEC.SANTOS                                           NaN
# DELEGACIA ELETRONICA                                     NaN
# DELEGACIA ELETRONICA                                     NaN
# DEL.SEC.SANTOS                                           NaN
# ...                                                      ...
# DELEGACIA ELETRONICA                          DEL.SEC.SANTOS
# DIV.POL.PORTO/AERO/PROT.TURISTA               DEL.SEC.SANTOS
# DELEGACIA ELETRONICA                          DEL.SEC.SANTOS
# DELEGACIA ELETRONICA                          DEL.SEC.SANTOS
# DEL.SEC.PRAIA GRANDE                          DEL.SEC.SANTOS
#
#                                 NOME_MUNICIPIO_CIRCUNSCRICAO
# NOME_SECCIONAL
# DEL.SEC.SANTOS                                           NaN
# DEL.SEC.SANTOS                                           NaN
# DELEGACIA ELETRONICA                                     NaN
# DELEGACIA ELETRONICA                                     NaN
# DEL.SEC.SANTOS                                           NaN
# ...                                                      ...
# DELEGACIA ELETRONICA                                  SANTOS
# DIV.POL.PORTO/AERO/PROT.TURISTA                       SANTOS
# DELEGACIA ELETRONICA                                  SANTOS
# DELEGACIA ELETRONICA                                  SANTOS
# DEL.SEC.PRAIA GRANDE                                  SANTOS
#
# [35910 rows x 14 columns]

# %%
# filtrando ocorrencias de estupro

df_occ = df_city[(df_city['RUBRICA'].str.upper().str.contains("ESTUPRO", regex=False, na=False, case=False))]
df_occ
# Out:
#                      NOME_MUNICIPIO DATA_REGISTRO   DATA_OCORRENCIA_BO  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE         SANTOS    2022-01-05  2021-11-20 00:00:00
# DEL.SEC.SANTOS               SANTOS    2022-01-09  2022-01-09 00:00:00
# DEL.SEC.SANTOS               SANTOS    2022-01-16  2022-01-15 00:00:00
# DEL.SEC.SANTOS               SANTOS    2022-01-11                  NaN
# DEL.SEC.SANTOS               SANTOS    2022-02-05  2021-10-17 00:00:00
# ...                             ...           ...                  ...
# DEL.SEC.SANTOS               SANTOS    2025-06-09           2025-03-15
# DEL.SEC.SANTOS               SANTOS    2025-06-18           2024-08-30
# DEL.SEC.SANTOS               SANTOS    2025-06-02           2025-06-02
# DEL.SEC.SANTOS               SANTOS    2025-06-17           2022-12-15
# DEL.SEC.SANTOS               SANTOS    2025-06-18           2025-06-18
#
#                      HORA_OCORRENCIA_BO     DESC_PERIODO    DESC_SUBTIPOLOCAL  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE           21:00:00              NaN  Comércio e Serviços
# DEL.SEC.SANTOS                 00:07:39              NaN           Residência
# DEL.SEC.SANTOS                 19:30:27              NaN           Residência
# DEL.SEC.SANTOS                      NaN  EM HORA INCERTA           Residência
# DEL.SEC.SANTOS                      NaN     DE MADRUGADA          Via Pública
# ...                                 ...              ...                  ...
# DEL.SEC.SANTOS                      NaN          A noite          Apartamento
# DEL.SEC.SANTOS                      NaN  Em hora incerta                 Casa
# DEL.SEC.SANTOS                      NaN          A tarde                 Casa
# DEL.SEC.SANTOS                      NaN          A noite                Casas
# DEL.SEC.SANTOS                 05:10:00              NaN          Via Pública
#
#                                  BAIRRO                            RUBRICA  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE        VILA MATIAS                 Art. 213 - Estupro
# DEL.SEC.SANTOS                   MARAPE  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS                   MACUCO                 Art. 213 - Estupro
# DEL.SEC.SANTOS        MORRO NOVA CINTRA  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS                   MACUCO                 Art. 213 - Estupro
# ...                                 ...                                ...
# DEL.SEC.SANTOS                    SABOO                 Estupro - Art. 213
# DEL.SEC.SANTOS                  CASTELO                 Estupro - Art. 213
# DEL.SEC.SANTOS           CHICO DE PAULA  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS              PIRATININGA  Estupro de vulneravel (art.217-A)
# DEL.SEC.SANTOS              JOSÉ MENINO                 Estupro - Art. 213
#
#                       MES_ESTATISTICA  ANO_ESTATISTICA  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE                1             2022
# DEL.SEC.SANTOS                      1             2022
# DEL.SEC.SANTOS                      1             2022
# DEL.SEC.SANTOS                      1             2022
# DEL.SEC.SANTOS                      2             2022
# ...                               ...              ...
# DEL.SEC.SANTOS                      6             2025
# DEL.SEC.SANTOS                      6             2025
# DEL.SEC.SANTOS                      6             2025
# DEL.SEC.SANTOS                      6             2025
# DEL.SEC.SANTOS                      6             2025
#
#                      NOME_DELEGACIA_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE                          NaN
# DEL.SEC.SANTOS                                NaN
# DEL.SEC.SANTOS                                NaN
# DEL.SEC.SANTOS                                NaN
# DEL.SEC.SANTOS                                NaN
# ...                                           ...
# DEL.SEC.SANTOS                    05º D.P. SANTOS
# DEL.SEC.SANTOS                    05º D.P. SANTOS
# DEL.SEC.SANTOS                    05º D.P. SANTOS
# DEL.SEC.SANTOS                    05º D.P. SANTOS
# DEL.SEC.SANTOS                    07º D.P. SANTOS
#
#                      NOME_DEPARTAMENTO_CIRCUNSCRICAO  \
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE                             NaN
# DEL.SEC.SANTOS                                   NaN
# DEL.SEC.SANTOS                                   NaN
# DEL.SEC.SANTOS                                   NaN
# DEL.SEC.SANTOS                                   NaN
# ...                                              ...
# DEL.SEC.SANTOS                    DEINTER 6 - SANTOS
# DEL.SEC.SANTOS                    DEINTER 6 - SANTOS
# DEL.SEC.SANTOS                    DEINTER 6 - SANTOS
# DEL.SEC.SANTOS                    DEINTER 6 - SANTOS
# DEL.SEC.SANTOS                    DEINTER 6 - SANTOS
#
#                      NOME_SECCIONAL_CIRCUNSCRICAO NOME_MUNICIPIO_CIRCUNSCRICAO
# NOME_SECCIONAL
# DEL.SEC.PRAIA GRANDE                          NaN                          NaN
# DEL.SEC.SANTOS                                NaN                          NaN
# DEL.SEC.SANTOS                                NaN                          NaN
# DEL.SEC.SANTOS                                NaN                          NaN
# DEL.SEC.SANTOS                                NaN                          NaN
# ...                                           ...                          ...
# DEL.SEC.SANTOS                     DEL.SEC.SANTOS                       SANTOS
# DEL.SEC.SANTOS                     DEL.SEC.SANTOS                       SANTOS
# DEL.SEC.SANTOS                     DEL.SEC.SANTOS                       SANTOS
# DEL.SEC.SANTOS                     DEL.SEC.SANTOS                       SANTOS
# DEL.SEC.SANTOS                     DEL.SEC.SANTOS                       SANTOS
#
# [226 rows x 14 columns]

# %% [markdown]
# # save

# %%
df_occ.to_csv("/content/drive/My Drive/projeto-integrador-I/data/processed/df_cleaned.csv", index=False)
