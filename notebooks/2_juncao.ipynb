# %% [markdown]
# # LIBS

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# # IMPORT

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# dados de 2022

first_path2022  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2022.csv"
second_path2022 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2022.csv"

first_df_2022  = pd.read_csv(first_path2022, index_col=0)
second_df_2022 = pd.read_csv(second_path2022, index_col=0)
# Out:
# /tmp/ipykernel_2117/2396412407.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_df_2022  = pd.read_csv(first_path2022, index_col=0)

# %%
'''
    em analise explorativa, notou-se que algumas colunas
    mantiveram suas features, mas foram renomeadas a partir
    de 2023, gerando uma incoerências do ano de 2022 com os
    restantes:

    cidade de ocorrencia deixou de ser nomeada como "CIDADE"
    e passou a ser nomeada como "NOME_MUNICIPIO";

    data de registro deixou de ser nemada como
    "DATA_COMUNICACAO_BO" e passou a ser nomeada
    como "DATA_REGISTRO";

    descrição de periodo de ocorrencia deicou de ser nomeada
    como "DESCR_PERIODO" e passou a ser nomeada como
    "DESC_PERIODO".

    descrição do local de ocorrencia deixou de ser nomeada
    como "DESCR_TIPOLOCAL e passou a ser nomeada como
    "DESCR_SUBTIPOLOCAL".
'''

# renomando as colunas de 2022
# renaming 2022 columns

first_df_2022_renamed  = first_df_2022.rename(columns={'CIDADE': 'NOME_MUNICIPIO',
                                                      'DATA_COMUNICACAO_BO': 'DATA_REGISTRO',
                                                      "DESCR_PERIODO": "DESC_PERIODO",
                                                      "DESCR_TIPOLOCAL": "DESCR_SUBTIPOLOCAL"})

second_df_2022_renamed = second_df_2022.rename(columns={'CIDADE': 'NOME_MUNICIPIO',
                                                      'DATA_COMUNICACAO_BO': 'DATA_REGISTRO',
                                                      "DESCR_PERIODO": "DESC_PERIODO",
                                                      "DESCR_TIPOLOCAL": "DESCR_SUBTIPOLOCAL"})

# %%
# dados de 2023

first_path2023  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2023.csv"
second_path2023 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2023.csv"

first_df_2023  = pd.read_csv(first_path2023, index_col=0)
second_df_2023 = pd.read_csv(second_path2023, index_col=0)
# Out:
# /tmp/ipykernel_2117/3528930263.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_df_2023  = pd.read_csv(first_path2023, index_col=0)

# %%
# dados de 2024

first_path2024  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2024.csv"
second_path2024 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2024.csv"

first_df_2024  = pd.read_csv(first_path2024, index_col=0)
second_df_2024 = pd.read_csv(second_path2024, index_col=0)
# Out:
# /tmp/ipykernel_2117/774496794.py:7: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   second_df_2024 = pd.read_csv(second_path2024, index_col=0)

# %%
# dados de 2025

first_path2025  = "/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2025.csv"
second_path2025 = "/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2025.csv"

first_df_2025  = pd.read_csv(first_path2025, index_col=0)
second_df_2025 = pd.read_csv(second_path2025, index_col=0)
# Out:
# /tmp/ipykernel_2117/3843521192.py:6: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_df_2025  = pd.read_csv(first_path2025, index_col=0)

# %%
second_df_2025['DESCR_TIPOLOCAL'].unique()
# Out:
# array(['Area não Ocupada', 'Centro Comercial/Empresarial', 'Residência',
#        'Via Pública', 'Terminal/Estação', 'Outros',
#        'Condomínio Comercial', 'Saúde', 'Shopping Center',
#        'Estacionamento/Garagem', 'Rodovia/Estrada',
#        'Entidade Assistencial', 'Escritório', 'Serviços e Bens Públicos',
#        'Repartição Pública', 'Hospedagem', 'Comércio e Serviços',
#        'Restaurante e Afins', 'Condomínio Residencial',
#        'Lazer e Recreação', 'Estabelecimento Bancário',
#        'Local Clandestino/Ilegal', 'Estabelecimento de Ensino', 'Favela',
#        'Internet', 'Templo e Afins', 'Estabelecimento Industrial',
#        'Unidade Rural', 'Estabelecimento Prisional', 'Hospital',
#        'Condomínio Residencial ', 'Ferroviário', 'Posto de Gasolina',
#        'Residencia'], dtype=object)

# %%
# o ano de 2025 tem 3 colunas a mais (cmd, ctl, cia)
df2025 = pd.concat([first_df_2025, second_df_2025], axis=0)
df2025 = df2025.drop(columns=['CMD', 'BTL', 'CIA', 'DESCR_SUBTIPOLOCAL'], axis=1) # colunas que só existem em 2025, remover para o merge
df2025 = df2025.rename(columns={
    'DESCR_TIPOLOCAL' : 'DESCR_SUBTIPOLOCAL' # renomear para manter o padrão adotado nos demais conjuntos
})

df2025.columns
# Out:
# Index(['NOME_SECCIONAL', 'NOME_DELEGACIA', 'NOME_MUNICIPIO', 'NUM_BO',
#        'ANO_BO', 'DATA_REGISTRO', 'DATA_OCORRENCIA_BO', 'HORA_OCORRENCIA_BO',
#        'DESC_PERIODO', 'DESCR_SUBTIPOLOCAL', 'BAIRRO', 'LOGRADOURO',
#        'NUMERO_LOGRADOURO', 'LATITUDE', 'LONGITUDE',
#        'NOME_DELEGACIA_CIRCUNSCRICAO', 'NOME_DEPARTAMENTO_CIRCUNSCRICAO',
#        'NOME_SECCIONAL_CIRCUNSCRICAO', 'NOME_MUNICIPIO_CIRCUNSCRICAO',
#        'RUBRICA', 'DESCR_CONDUTA', 'NATUREZA_APURADA', 'MES_ESTATISTICA',
#        'ANO_ESTATISTICA'],
#       dtype='object')

# %%
print(
       len(first_df_2022.columns) == len(second_df_2022.columns)
    == len(first_df_2023.columns) == len(second_df_2023.columns)
    == len(first_df_2024.columns) == len(second_df_2024.columns)
    == len(df2025.columns)
    )
# Out:
# True

# %% [markdown]
# # MERGE

# %%
# merge dos dados

list_df = [first_df_2022_renamed, second_df_2022_renamed,
           first_df_2023, second_df_2023,
           first_df_2024, second_df_2024,
           df2025]

df_merged = pd.concat(list_df, axis=0)
df_merged.tail()
# Out:
#                             NOME_SECCIONAL              NOME_DELEGACIA  \
# NOME_DEPARTAMENTO
# DEMACRO            DEL.SEC.TABOÃO DA SERRA    02º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA    01º D.P. TABOÃO DA SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  DISE- DEL.SEC.TABOÃO SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA  DISE- DEL.SEC.TABOÃO SERRA
# DEMACRO            DEL.SEC.TABOÃO DA SERRA    02º D.P. TABOÃO DA SERRA
#
#                     NOME_MUNICIPIO  NUM_BO  ANO_BO DATA_REGISTRO  \
# NOME_DEPARTAMENTO
# DEMACRO             EMBU DAS ARTES  SE6626    2025    2025-12-12
# DEMACRO            TABOAO DA SERRA  SJ9736    2025    2025-12-16
# DEMACRO            TABOAO DA SERRA  SK1616    2025    2025-12-16
# DEMACRO            TABOAO DA SERRA  SR6536    2025    2025-12-22
# DEMACRO            TABOAO DA SERRA  SS1580    2025    2025-12-22
#
#                   DATA_OCORRENCIA_BO HORA_OCORRENCIA_BO DESC_PERIODO  \
# NOME_DEPARTAMENTO
# ...

# %%
# normalizando "desc"

df = df_merged.rename(columns={'DESCR_SUBTIPOLOCAL': 'DESC_SUBTIPOLOCAL'})
df.columns
# Out:
# Index(['NOME_SECCIONAL', 'NOME_DELEGACIA', 'NOME_MUNICIPIO', 'NUM_BO',
#        'ANO_BO', 'DATA_REGISTRO', 'DATA_OCORRENCIA_BO', 'HORA_OCORRENCIA_BO',
#        'DESC_PERIODO', 'DESC_SUBTIPOLOCAL', 'BAIRRO', 'LOGRADOURO',
#        'NUMERO_LOGRADOURO', 'LATITUDE', 'LONGITUDE',
#        'NOME_DELEGACIA_CIRCUNSCRIÇÃO', 'NOME_DEPARTAMENTO_CIRCUNSCRIÇÃO',
#        'NOME_SECCIONAL_CIRCUNSCRIÇÃO', 'NOME_MUNICIPIO_CIRCUNSCRIÇÃO',
#        'RUBRICA', 'DESCR_CONDUTA', 'NATUREZA_APURADA', 'MES_ESTATISTICA',
#        'ANO_ESTATISTICA', 'NOME_DELEGACIA_CIRCUNSCRICAO',
#        'NOME_DEPARTAMENTO_CIRCUNSCRICAO', 'NOME_SECCIONAL_CIRCUNSCRICAO',
#        'NOME_MUNICIPIO_CIRCUNSCRICAO'],
#       dtype='object')

# %% [markdown]
# # SAVE

# %%
df.to_csv("/content/drive/My Drive/projeto-integrador-I/data/processed/df_merged.csv", index=False)
