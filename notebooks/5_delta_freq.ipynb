# %% [markdown]
# # libs e dados

# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
delta = pd.read_csv('/content/drive/MyDrive/projeto-integrador-I/data/processed/delta_table.csv')
delta.head()
# Out:
#    Unnamed: 0  count
# 0           0     52
# 1           1     34
# 2           4     10
# 3           2      8
# 4           9      6

# %%
delta = delta.rename(columns={"Unnamed: 0": "delta"})
delta.head()
# Out:
#    delta  count
# 0      0     52
# 1      1     34
# 2      4     10
# 3      2      8
# 4      9      6

# %% [markdown]
# # tabela de frequencia

# %%
# classes da tabela
k = int(np.ceil(1 +  3.3 * np.log10(len(delta)))) # regra de sturges

# %%
# classes com amplitude variável
delta['classe'] = pd.qcut(delta['delta'], q=k, duplicates='drop')

# tabela inicial com frequencia de classe
freq = delta.groupby('classe', observed=False)['count'].sum().reset_index()
freq.columns = ['_intervalo', 'fi'] # _intervalo é apenas um suporte para os proximos calculos
freq.head()
# Out:
#            _intervalo   fi
# 0     (-0.001, 7.286]  116
# 1       (7.286, 31.0]   26
# 2      (31.0, 64.429]   16
# 3   (64.429, 154.857]   16
# 4  (154.857, 455.571]   14

# %%
# classes da tabela
freq['intervalos'] = freq['_intervalo'].apply(
    lambda x: f"{int(x.left)} |- {int(x.right)}"
)

freq
# Out:
#             _intervalo   fi    intervalos
# 0      (-0.001, 7.286]  116        0 |- 7
# 1        (7.286, 31.0]   26       7 |- 31
# 2       (31.0, 64.429]   16      31 |- 64
# 3    (64.429, 154.857]   16     64 |- 154
# 4   (154.857, 455.571]   14    154 |- 455
# 5  (455.571, 1030.143]   14   455 |- 1030
# 6   (1030.143, 7057.0]   16  1030 |- 7057

# %%
# classes medias (xi)
freq['xi'] = freq['_intervalo'].apply(
    lambda x: float((x.left + x.right) / 2)
).round(1)

freq
# Out:
#             _intervalo   fi    intervalos         xi
# 0      (-0.001, 7.286]  116        0 |- 7     3.6425
# 1        (7.286, 31.0]   26       7 |- 31    19.1430
# 2       (31.0, 64.429]   16      31 |- 64    47.7145
# 3    (64.429, 154.857]   16     64 |- 154   109.6430
# 4   (154.857, 455.571]   14    154 |- 455   305.2140
# 5  (455.571, 1030.143]   14   455 |- 1030   742.8570
# 6   (1030.143, 7057.0]   16  1030 |- 7057  4043.5715

# %%
# produto medio
freq['xifi'] = freq['xi'].astype(float) * freq['fi'].astype(float)
freq
# Out:
#             _intervalo   fi    intervalos         xi       xifi
# 0      (-0.001, 7.286]  116        0 |- 7     3.6425    422.530
# 1        (7.286, 31.0]   26       7 |- 31    19.1430    497.718
# 2       (31.0, 64.429]   16      31 |- 64    47.7145    763.432
# 3    (64.429, 154.857]   16     64 |- 154   109.6430   1754.288
# 4   (154.857, 455.571]   14    154 |- 455   305.2140   4272.996
# 5  (455.571, 1030.143]   14   455 |- 1030   742.8570  10399.998
# 6   (1030.143, 7057.0]   16  1030 |- 7057  4043.5715  64697.144

# %%
# frequencia relativa(fr)
total = freq['fi'].sum()
freq['fr'] = freq['fi'] / total * 100
freq
# Out:
#             _intervalo   fi    intervalos         xi       xifi         fr
# 0      (-0.001, 7.286]  116        0 |- 7     3.6425    422.530  53.211009
# 1        (7.286, 31.0]   26       7 |- 31    19.1430    497.718  11.926606
# 2       (31.0, 64.429]   16      31 |- 64    47.7145    763.432   7.339450
# 3    (64.429, 154.857]   16     64 |- 154   109.6430   1754.288   7.339450
# 4   (154.857, 455.571]   14    154 |- 455   305.2140   4272.996   6.422018
# 5  (455.571, 1030.143]   14   455 |- 1030   742.8570  10399.998   6.422018
# 6   (1030.143, 7057.0]   16  1030 |- 7057  4043.5715  64697.144   7.339450

# %%
# frequencia acumulada absoluta (fac)
freq['fac'] = freq['fi'].cumsum()
freq
# Out:
#             _intervalo   fi    intervalos         xi       xifi         fr  \
# 0      (-0.001, 7.286]  116        0 |- 7     3.6425    422.530  53.211009
# 1        (7.286, 31.0]   26       7 |- 31    19.1430    497.718  11.926606
# 2       (31.0, 64.429]   16      31 |- 64    47.7145    763.432   7.339450
# 3    (64.429, 154.857]   16     64 |- 154   109.6430   1754.288   7.339450
# 4   (154.857, 455.571]   14    154 |- 455   305.2140   4272.996   6.422018
# 5  (455.571, 1030.143]   14   455 |- 1030   742.8570  10399.998   6.422018
# 6   (1030.143, 7057.0]   16  1030 |- 7057  4043.5715  64697.144   7.339450
#
#    fac
# 0  116
# 1  142
# 2  158
# 3  174
# 4  188
# 5  202
# 6  218

# %%
# frequencia relativa acumulada (fri)
freq['fri'] = freq['fr'].cumsum()
freq
# Out:
#             _intervalo   fi    intervalos         xi       xifi         fr  \
# 0      (-0.001, 7.286]  116        0 |- 7     3.6425    422.530  53.211009
# 1        (7.286, 31.0]   26       7 |- 31    19.1430    497.718  11.926606
# 2       (31.0, 64.429]   16      31 |- 64    47.7145    763.432   7.339450
# 3    (64.429, 154.857]   16     64 |- 154   109.6430   1754.288   7.339450
# 4   (154.857, 455.571]   14    154 |- 455   305.2140   4272.996   6.422018
# 5  (455.571, 1030.143]   14   455 |- 1030   742.8570  10399.998   6.422018
# 6   (1030.143, 7057.0]   16  1030 |- 7057  4043.5715  64697.144   7.339450
#
#    fac         fri
# 0  116   53.211009
# 1  142   65.137615
# 2  158   72.477064
# 3  174   79.816514
# 4  188   86.238532
# 5  202   92.660550
# 6  218  100.000000

# %%
# tablea final organizada
table = freq[['intervalos', 'fi', 'xi', 'xifi', 'fr', 'fac', 'fri']].copy()
table = table.reset_index(drop=True)
table
# Out:
#      intervalos   fi         xi       xifi         fr  fac         fri
# 0        0 |- 7  116     3.6425    422.530  53.211009  116   53.211009
# 1       7 |- 31   26    19.1430    497.718  11.926606  142   65.137615
# 2      31 |- 64   16    47.7145    763.432   7.339450  158   72.477064
# 3     64 |- 154   16   109.6430   1754.288   7.339450  174   79.816514
# 4    154 |- 455   14   305.2140   4272.996   6.422018  188   86.238532
# 5   455 |- 1030   14   742.8570  10399.998   6.422018  202   92.660550
# 6  1030 |- 7057   16  4043.5715  64697.144   7.339450  218  100.000000

# %%
table.to_excel('/content/drive/MyDrive/projeto-integrador-I/data/processed/freq_table.xlsx')

# %% [markdown]
# # estatisticas estimadas

# %%
# media estimada 
mean = int(table['xifi'].sum() / total)
mean
# Out:
# 379

# %%
# traduzindo para um formato de calendario
mean_mounth = int(mean / 30)
mean_days   = mean % 30

mean_mounth, mean_days
# Out:
# (12, 19)

# %% [markdown]
# # tabela de frequencia da primeira semana

# %%
# ocorrencias notificadas dentro da primeira semana (até 7 dias)
week = delta[delta['delta'] <= 7].sort_values(by='delta')
week = week.drop(columns='classe')
week = week.rename(columns={'delta' : 'classe'})
week
# Out:
#     classe  count
# 0        0     52
# 1        1     34
# 3        2      8
# 8        3      4
# 2        4     10
# 14       5      2
# 9        6      4
# 40       7      2

# %%
# frequência de cada intervalo (fi)
week = week.rename(columns={'count' : 'fi'})
week
# Out:
#     classe  fi
# 0        0  52
# 1        1  34
# 3        2   8
# 8        3   4
# 2        4  10
# 14       5   2
# 9        6   4
# 40       7   2

# %%
# frequencia relativa (fr)
week_total = week['fi'].sum()
week['fr'] = week['fi'] / week_total * 100
week
# Out:
#     classe  fi         fr
# 0        0  52  44.827586
# 1        1  34  29.310345
# 3        2   8   6.896552
# 8        3   4   3.448276
# 2        4  10   8.620690
# 14       5   2   1.724138
# 9        6   4   3.448276
# 40       7   2   1.724138

# %%
# frequencia acumulada absoluta (fac)
week['fac'] = week['fi'].cumsum()
week
# Out:
#     classe  fi         fr  fac
# 0        0  52  44.827586   52
# 1        1  34  29.310345   86
# 3        2   8   6.896552   94
# 8        3   4   3.448276   98
# 2        4  10   8.620690  108
# 14       5   2   1.724138  110
# 9        6   4   3.448276  114
# 40       7   2   1.724138  116

# %%
# frequencia relativa acumulada (fri)
week['fri'] = week['fr'].cumsum()
week
# Out:
#     classe  fi         fr  fac         fri
# 0        0  52  44.827586   52   44.827586
# 1        1  34  29.310345   86   74.137931
# 3        2   8   6.896552   94   81.034483
# 8        3   4   3.448276   98   84.482759
# 2        4  10   8.620690  108   93.103448
# 14       5   2   1.724138  110   94.827586
# 9        6   4   3.448276  114   98.275862
# 40       7   2   1.724138  116  100.000000

# %%
week.to_excel('/content/drive/MyDrive/projeto-integrador-I/data/processed/week_table.xlsx')
