# %% [markdown]
# # libs

# %%
import pandas as pd
from google.colab import drive

# %% [markdown]
# # imports

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# dados de 2022
path2022 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2022.xlsx"
first_semester_2022 = pd.read_excel(path2022, sheet_name=0)
second_semester_2022 = pd.read_excel(path2022, sheet_name=1)

# %%
# dados de 2023
path2023 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2023.xlsx"
first_semester_2023 = pd.read_excel(path2023, sheet_name=0)
second_semester_2023 = pd.read_excel(path2023, sheet_name=1)

# %%
# dados de 2024
path2024 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2024.xlsx"
first_semester_2024 = pd.read_excel(path2024, sheet_name=0)
second_semester_2024 = pd.read_excel(path2024, sheet_name=1)

# %%
# dados de 2025

path2025 = "/content/drive/My Drive/projeto-integrador-I/data/raw/SPDadosCriminais_2025.xlsx"
first_semester_2025 = pd.read_excel(path2025, sheet_name=1)     # em 2025 foi inserido um dicionario de dados na posição 0
second_semester_2025 = pd.read_excel(path2025, sheet_name=2)

# %% [markdown]
# # save

# %%
# 2022
first_semester_2022.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2022.csv", index=False)
second_semester_2022.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2022.csv", index=False)

# 2023
first_semester_2023.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2023.csv", index=False)
second_semester_2023.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2023.csv", index=False)

# 2024
first_semester_2024.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2024.csv", index=False)
second_semester_2024.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2024.csv", index=False)

# 2025
first_semester_2025.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/1st_2025.csv", index=False)
second_semester_2025.to_csv("/content/drive/My Drive/projeto-integrador-I/data/raw/2nd_2025.csv", index=False)
